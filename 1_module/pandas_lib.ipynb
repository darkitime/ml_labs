# %% [markdown]
# Pandas - библиотека для работы с данными. Активно используется в современном data science

# %%
import pandas as pd
import numpy as np

# %%
#pd.Series - одномерный набор данных
some_list = [1, 3, 5, np.nan, 6, 8]
ser_1 = pd.Series(some_list)
ser_1
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
ind = ['1st day', '2nd day', '3rd day', '4th day', '5th day', '6th day']
ser_2 = pd.Series(some_list, index=ind)
ser_2
# Out:
# 1st day    1.0
# 2nd day    3.0
# 3rd day    5.0
# 4th day    NaN
# 5th day    6.0
# 6th day    8.0
# dtype: float64

# %%
ser_2['4th day']
# Out:
# np.float64(nan)

# %%
ser_3 = pd.Series(some_list,index=ind,name='Temperature')
ser_3
# Out:
# 1st day    1.0
# 2nd day    3.0
# 3rd day    5.0
# 4th day    NaN
# 5th day    6.0
# 6th day    8.0
# Name: Temperature, dtype: float64

# %%
#Индексирование
print(ser_3.iloc[0])
print(ser_3.iloc[1:3])
print(ser_3.iloc[::-1])
# Out:
# 1.0
# 2nd day    3.0
# 3rd day    5.0
# Name: Temperature, dtype: float64
# 6th day    8.0
# 5th day    6.0
# 4th day    NaN
# 3rd day    5.0
# 2nd day    3.0
# 1st day    1.0
# Name: Temperature, dtype: float64

# %%
#Индексирование по условиям
date_range = pd.date_range('20190101', periods = 10)
ser_4 = pd.Series(np.random.rand(10), index = date_range)
ser_4
# Out:
# 2019-01-01    0.558088
# 2019-01-02    0.366992
# 2019-01-03    0.163033
# 2019-01-04    0.004226
# 2019-01-05    0.336645
# 2019-01-06    0.830346
# 2019-01-07    0.009388
# 2019-01-08    0.048144
# 2019-01-09    0.342871
# 2019-01-10    0.463957
# Freq: D, dtype: float64

# %%
ser_4 > 0.5
# Out:
# 2019-01-01     True
# 2019-01-02    False
# 2019-01-03    False
# 2019-01-04    False
# 2019-01-05    False
# 2019-01-06     True
# 2019-01-07    False
# 2019-01-08    False
# 2019-01-09    False
# 2019-01-10    False
# Freq: D, dtype: bool

# %%
ser_4[ser_4>0.5]
# Out:
# 2019-01-01    0.558088
# 2019-01-06    0.830346
# dtype: float64

# %%
ser_4[(ser_4>0.6)|(ser_4<0.2)]
# Out:
# 2019-01-03    0.163033
# 2019-01-04    0.004226
# 2019-01-06    0.830346
# 2019-01-07    0.009388
# 2019-01-08    0.048144
# dtype: float64

# %%
ser_4[(ser_4>0.6)&(ser_4<0.2)]
# Out:
# Series([], Freq: D, dtype: float64)

# %%
#Сортировки по индексам
ser_4.sort_index()
# Out:
# 2019-01-01    0.558088
# 2019-01-02    0.366992
# 2019-01-03    0.163033
# 2019-01-04    0.004226
# 2019-01-05    0.336645
# 2019-01-06    0.830346
# 2019-01-07    0.009388
# 2019-01-08    0.048144
# 2019-01-09    0.342871
# 2019-01-10    0.463957
# Freq: D, dtype: float64

# %%
#Сортировка по значени
ser_4.sort_values()
# Out:
# 2019-01-04    0.004226
# 2019-01-07    0.009388
# 2019-01-08    0.048144
# 2019-01-03    0.163033
# 2019-01-05    0.336645
# 2019-01-09    0.342871
# 2019-01-02    0.366992
# 2019-01-10    0.463957
# 2019-01-01    0.558088
# 2019-01-06    0.830346
# dtype: float64

# %%
#Операции с series
ser_4+100
# Out:
# 2019-01-01    100.558088
# 2019-01-02    100.366992
# 2019-01-03    100.163033
# 2019-01-04    100.004226
# 2019-01-05    100.336645
# 2019-01-06    100.830346
# 2019-01-07    100.009388
# 2019-01-08    100.048144
# 2019-01-09    100.342871
# 2019-01-10    100.463957
# Freq: D, dtype: float64

# %%
np.cos(ser_4)
# Out:
# 2019-01-01    0.848269
# 2019-01-02    0.933411
# 2019-01-03    0.986740
# 2019-01-04    0.999991
# 2019-01-05    0.943868
# 2019-01-06    0.674621
# 2019-01-07    0.999956
# 2019-01-08    0.998841
# 2019-01-09    0.941793
# 2019-01-10    0.894289
# Freq: D, dtype: float64

# %%
term_1=pd.Series(np.random.randint(0,10,5))
term_2=pd.Series(np.random.randint(0,10,6))
term_1+term_2
# Out:
# 0    5.0
# 1    6.0
# 2    2.0
# 3    5.0
# 4    8.0
# 5    NaN
# dtype: float64

# %%
term_1.shape
# Out:
# (5,)

# %% [markdown]
# #pd.DataFrame- таблицы

# %%
#Создание и основные объекты
some_dict = {
    'one': pd.Series([1,2,3], index=['a','b','c']),
    'two': pd.Series([1,2,3,4], index=['a','b','c','d']),
    'three': pd.Series([5,6,7,8], index=['a','b','c','d']),
}
df=pd.DataFrame(some_dict)
df
# Out:
#    one  two  three
# a  1.0    1      5
# b  2.0    2      6
# c  3.0    3      7
# d  NaN    4      8

# %%
some_array = [[1,1,5],[2,2,6],[3,3,7],[np.nan, 4, 8]]
df = pd.DataFrame(some_array, index =['a','b','c','d'],columns=['one','two','three'])
df
# Out:
#    one  two  three
# a  1.0    1      5
# b  2.0    2      6
# c  3.0    3      7
# d  NaN    4      8

# %%
df.values
# Out:
# array([[ 1.,  1.,  5.],
#        [ 2.,  2.,  6.],
#        [ 3.,  3.,  7.],
#        [nan,  4.,  8.]])

# %%
df.columns
# Out:
# Index(['one', 'two', 'three'], dtype='str')

# %%
df.columns=['first_column','second_column','third_column']
df.index = [1, 2, 3, 4]
df
# Out:
#    first_column  second_column  third_column
# 1           1.0              1             5
# 2           2.0              2             6
# 3           3.0              3             7
# 4           NaN              4             8

# %%
#Индексирование
first_column = df['first_column']
first_column
# Out:
# 1    1.0
# 2    2.0
# 3    3.0
# 4    NaN
# Name: first_column, dtype: float64

# %%
df.first_column
# Out:
# 1    1.0
# 2    2.0
# 3    3.0
# 4    NaN
# Name: first_column, dtype: float64

# %%
subset_dataframe = df[['first_column','second_column']]
subset_dataframe
# Out:
#    first_column  second_column
# 1           1.0              1
# 2           2.0              2
# 3           3.0              3
# 4           NaN              4

# %%
one_column_dataframe = df[['first_column']]
one_column_dataframe
# Out:
#    first_column
# 1           1.0
# 2           2.0
# 3           3.0
# 4           NaN

# %%
#df нельзя обратиться по индексу 
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\miniconda\envs\ml\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[:1]
# Out:
#    first_column  second_column  third_column
# 1           1.0              1             5

# %%
df[1:4]
# Out:
#    first_column  second_column  third_column
# 2           2.0              2             6
# 3           3.0              3             7
# 4           NaN              4             8

# %%
#По индексам
df.iloc[1:3,:2]
# Out:
#    first_column  second_column
# 2           2.0              2
# 3           3.0              3

# %%
df.loc[1:3,['first_column','second_column']]
# Out:
#    first_column  second_column
# 1           1.0              1
# 2           2.0              2
# 3           3.0              3

# %%
#Модификации датасета, создание новых колонок
new_column = [5,2,1,4]
df['new_column'] = new_column
df
# Out:
#    first_column  second_column  third_column  new_column
# 1           1.0              1             5           5
# 2           2.0              2             6           2
# 3           3.0              3             7           1
# 4           NaN              4             8           4

# %%
df['first_column'] = df['first_column']*10
df
# Out:
#    first_column  second_column  third_column  new_column
# 1          10.0              1             5           5
# 2          20.0              2             6           2
# 3          30.0              3             7           1
# 4           NaN              4             8           4

# %%
#Титаник
df = pd.read_csv('Titanic-Dataset.csv',index_col='PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
y=df['Survived']
y
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
df.tail(10)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 882                 0       3                        Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 884                 0       2             Banfield, Mr. Frederick James
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# ...

# %%
df.shape
# Out:
# (891, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#max/min
df['Age'].min(), df['Age'].max(), df.Age.mean()
# Out:
# (np.float64(0.42), np.float64(80.0), np.float64(29.69911764705882))

# %%
#Подсчет каждого из значений
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.groupby(['Pclass'])

# %%
df.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
#Слияния таблиц
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
#       1 #Слияния таблиц
# ----> 2 df.drop(['Survived'])
#
# File d:\miniconda\envs\ml\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File d:\miniconda\envs\ml\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# ...

# %%
y.index = np.arange(1, 892)

# %%
y=y.sample(frac=1)
y.head()
# Out:
# 21     0
# 117    0
# 807    0
# 309    0
# 298    0
# Name: Survived, dtype: int64

# %%
y.name = 'idk'
df = df.join(y)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  idk
# 1    male  22.0      1      0         A/5 21171   7.2500   NaN        S    0
# 2  female  38.0      1      0          PC 17599  71.2833   C85        C    1
# 3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    1
# 4  female  35.0      1      0            113803  53.1000  C123        S    1
# 5    male  35.0      0      0            373450   8.0500   NaN        S    0

# %%
(df.Survived.value_counts())
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.groupby(['Sex'])['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
corr_data = df[['Sex','Age','Survived']]
corr_data.Sex = (corr_data.Sex == 'female').astype(int)

# %%
corr_data.head()
# Out:
#    Sex   Age  Survived
# 1    0  22.0         0
# 2    1  38.0         1
# 3    1  26.0         1
# 4    1  35.0         1
# 5    0  35.0         0

# %%
corr_data.corr()
# Out:
#                Sex       Age  Survived
# Sex       1.000000 -0.093254  0.543351
# Age      -0.093254  1.000000 -0.077221
# Survived  0.543351 -0.077221  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(
    corr_data.corr(), annot = True, cmap = 'coolwarm',
    vmin =-1,vmax=1,annot_kws={"size":16}
)
# Out:
# <Axes: >
