# %%
import pandas as pd

# %%
pd.get_option
# Out:
# <function pandas.get_option(pat: 'str') -> 'Any'>

# %%
student_data=[
  [1, 15],
  [2, 11],
  [3, 11],
  [4, 20]
]

def createDataframe(student_data: list[list[int]]) -> pd.DataFrame:
    df = pd.DataFrame(student_data, columns=['student_id','age'])
    return df

print(createDataframe(student_data))
df=createDataframe(student_data)
# Out:
#    student_id  age
# 0           1   15
# 1           2   11
# 2           3   11
# 3           4   20
#    student_id  age
# 0           1   15
# 1           2   11
# 2           3   11
# 3           4   20

# %%
def getDataframeSize(players: pd.DataFrame) -> list[int]:
    res =[df.shape[0],df.shape[1]]
    return res

print(getDataframeSize(df))
# Out:
# [4, 2]

# %%
df._drop_labels_or_levels
